# %%
import pandas as pd

# %%
df_principal = pd.read_excel("/content/Tabela de Ações Pura.xlsx", sheet_name="Principal")
df_principal
# Out:
#     Ativo       Data  Último (R$)  Var. Dia (%)  Var. Dia (%).1  \
# 0   USIM5 2024-01-26         9.50          5.20           11.76
# 1   CMIN3 2024-01-26         6.82          2.40            2.40
# 2   PETR3 2024-01-26        41.96          2.19            7.73
# 3   SUZB3 2024-01-26        52.91          2.04            2.14
# 4   CPFE3 2024-01-26        37.10          2.03            2.49
# ..    ...        ...          ...           ...             ...
# 76  CRFB3 2024-01-26        10.71         -2.45           -9.47
# 77  BHIA3 2024-01-26         8.70         -2.46           -6.95
# 78  RENT3 2024-01-26        56.24         -3.63           -6.41
# 79  CVCB3 2024-01-26         3.07         -4.36           -5.54
# 80  GOLL4 2024-01-26         5.92         -8.07          -15.91
#
#     Var. Dia (%).2  Var. Dia (%).3  Var. Dia (%).4  Var. Dia (%).5  \
# 0             2.26            2.26           15.97            9.18
# 1           -12.11          -12.11           50.56            6.66
# 2             7.64            7.64           77.55           40.81
# 3            -4.89           -4.89           18.85           51.89
# 4            -3.66           -3.66           20.70           36.37
# ..             ...             ...             ...             ...
# 76          -13.98          -13.98          -32.72           10.70
# 77          -23.55          -23.55          -85.74            8.67
# 78          -11.57          -11.57           -2.77           56.04
# 79          -12.29          -12.29          -36.83            3.05
# 80          -34.00          -34.00          -25.44            5.51
#
#     Var. Dia (%).6  ...    Variação $  Resultado   Nome da Empresa  \
# 0             9.56  ...  2.418897e+08      Subiu          Usiminas
# 1             6.86  ...  1.775160e+08      Subiu     CSN Mineração
# 2            42.34  ...  2.140059e+09      Subiu         Petrobras
# 3            53.17  ...  7.229463e+08      Subiu            Suzano
# 4            37.32  ...  1.385740e+08      Subiu      CPFL Energia
# ..             ...  ...           ...        ...               ...
# 76           11.08  ... -1.436355e+08     Desceu  Carrefour Brasil
# 77            8.95  ... -2.081024e+07     Desceu       Casas Bahia
# 78           58.90  ... -1.807433e+09     Desceu          Localiza
# 79            3.23  ... -7.355741e+07     Desceu               CVC
# 80            6.02  ... -1.029932e+08     Desceu               GOL
#
#                                              Segmento  Idade  \
# 0                                          Siderurgia   21.0
# 1                                           Mineração   20.0
# 2                     Petróleo, Gás e Biocombustíveis   21.0
# 3                                    Papel e Celulose   21.0
# 4                                    Energia Elétrica   20.0
# ..                                                ...    ...
# 76                                           Comércio   20.0
# 77                                           Comércio   20.0
# 78  Aluguel de carros, Transporte de Valores e Ges...   21.0
# 79                                  Viagens e Turismo   20.0
# 80                                   Transporte Aéreo   14.0
#
#            Cat_Idade Variação Sem % Valor Inicial (R$).1  Variação $.1  \
# 0   Menos de 50 anos         0.1176             8.500358  5.149330e+08
# 1   Menos de 50 anos         0.0240             6.660156  1.775160e+08
# 2   Menos de 50 anos         0.0773            38.949225  7.165276e+09
# 3   Menos de 50 anos         0.0214            51.801449  7.576423e+08
# 4   Menos de 50 anos         0.0249            36.198654  1.692121e+08
# ..               ...            ...                  ...           ...
# 76  Menos de 50 anos        -0.0947            11.830332 -5.982470e+08
# 77  Menos de 50 anos        -0.0695             9.349812 -6.163014e+07
# 78  Menos de 50 anos        -0.0641            60.091890 -3.286442e+09
# 79  Menos de 50 anos        -0.0554             3.250053 -9.463272e+07
# 80  Menos de 50 anos        -0.1591             7.040076 -2.219822e+08
#
#    Resultado.1
# 0        Subiu
# 1        Subiu
# 2        Subiu
# 3        Subiu
# 4        Subiu
# ..         ...
# 76      Desceu
# 77      Desceu
# 78      Desceu
# 79      Desceu
# 80      Desceu
#
# [81 rows x 24 columns]

# %%
df_total_acoes = pd.read_excel("/content/Tabela de Ações Pura.xlsx", sheet_name="Total_de_acoes")
df_total_acoes
# Out:
#                       Código  Qtde. Teórica
# 0                      RRRP3   2.356656e+08
# 1                      ALOS3   5.326166e+08
# 2                      ALPA4   1.767340e+08
# 3                      ABEV3   4.394246e+09
# 4                      ARZZ3   6.230589e+07
# ..                       ...            ...
# 84                     VBBR3   1.114413e+09
# 85                     WEGE3   1.481593e+09
# 86                     YDUQ3   2.893479e+08
# 87  Quantidade Teórica Total   9.637210e+10
# 88                   Redutor   1.704785e+07
#
# [89 rows x 2 columns]

# %%
df_ticker = pd.read_excel("/content/Tabela de Ações Pura.xlsx", sheet_name="Ticker")
df_ticker
# Out:
#     Ticker            Nome
# 0    MGLU3  Magazine Luiza
# 1    HAPV3         Hapvida
# 2    PETR4       Petrobras
# 3    B3SA3              B3
# 4    USIM5        Usiminas
# ..     ...             ...
# 530  TKNO3           Tekno
# 531  COCE6          Coelce
# 532  MGEL3         Mangels
# 533  CTSA8      Santanense
# 534  MMAQ4   Minasmáquinas
#
# [535 rows x 2 columns]

# %%
df_chatgpt = pd.read_excel("/content/Tabela de Ações Pura.xlsx", sheet_name="Chatgpt")
df_chatgpt
# Out:
#              Empresa                                           Segmento  \
# 0           Usiminas                                         Siderurgia
# 1      CSN Mineração                                          Mineração
# 2          Petrobras                    Petróleo, Gás e Biocombustíveis
# 3             Suzano                                   Papel e Celulose
# 4       CPFL Energia                                   Energia Elétrica
# ..               ...                                                ...
# 73  Carrefour Brasil                                           Comércio
# 74       Casas Bahia                                           Comércio
# 75          Localiza  Aluguel de carros, Transporte de Valores e Ges...
# 76               CVC                                  Viagens e Turismo
# 77               GOL                                   Transporte Aéreo
#
#    Idade (anos até 2021)
# 0                     60
# 1                     80
# 2                     68
# 3                     97
# 4                    108
# ..                   ...
# 73                    45
# 74                    68
# 75                    48
# 76                    50
# 77                    21
#
# [78 rows x 3 columns]
